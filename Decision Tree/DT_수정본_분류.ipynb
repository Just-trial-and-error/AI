# %% [markdown]
# # 의사결정나무(Decision Tree)실습

# %% [markdown]
# ## 1. 모듈/라이브러리 불러오기

# %%
#!conda install -y numpy

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from graphviz import Source
from IPython.display import Image

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.metrics import accuracy_score,recall_score, precision_score
from sklearn.metrics import confusion_matrix, roc_curve,f1_score, auc
from sklearn.metrics import classification_report,roc_auc_score


sns.set_style("whitegrid")

# %%
#<img src='./Decision Tree/Classification_유방암_WDBC/for_markdown/2.png'>

Image('C:/Users/AERO/Desktop/AI_practice/Decision Tree/Classification_유방암_WDBC/for_markdown/2.png')

# %% [markdown]
# ## 2. 데이터 불러오기

# %%
data = pd.read_csv("BreastCancerWisconsin.csv")
print("- Data has {} rows and {} columns.".format(*data.shape))
print("- Column names: ", list(data.columns))

# %%
print(data.shape)
print(data.head(10))

# %% [markdown]
# ## 3. 탐색적 데이터 분석

# %% [markdown]
# ### [TIP0] sns.pairplot을 이용하여 설명변수의 분포(히스토그램) 및 설명변수들 간의 관계(산점도)를 그리고, 특성을 파악

# %%
fig, ax = plt.subplots()
sns.pairplot(data=data)
plt.savefig('pairplot.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-729c4e1e849d> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 sns.pairplot(data=data)
#       3 #plt.savefig('pairplot.png')
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1989     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1990                     hue_order=hue_order, palette=palette, corner=corner,
# -> 1991                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    1992
#    1993     # Add the markers here as PairGrid has figured out how many levels of the
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1248         if despine:
#    1249             utils.despine(fig=fig)
# -> 1250         self.tight_layout(pad=layout_pad)
#    1251
#    1252     def map(self, func, **kwargs):
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\seaborn\axisgrid.py in tight_layout(self, *args, **kwargs)
#      62         if self._tight_layout_pad is not None:
#      63             kwargs.setdefault("pad", self._tight_layout_pad)
# ---> 64         self.fig.tight_layout(*args, **kwargs)
#      65
#      66     def add_legend(self, legend_data=None, title=None, label_order=None,
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2613             kwargs = get_tight_layout_figure(
#    2614                 self, self.axes, subplotspec_list, renderer,
# -> 2615                 pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2616         if kwargs:
#    2617             self.subplots_adjust(**kwargs)
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     306                                      subplot_list=subplot_list,
#     307                                      ax_bbox_list=ax_bbox_list,
# --> 308                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     309
#     310     # kwargs can be none if tight_layout fails...
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      82             if ax.get_visible():
#      83                 try:
# ---> 84                     bb += [ax.get_tightbbox(renderer, for_layout_only=True)]
#      85                 except TypeError:
#      86                     bb += [ax.get_tightbbox(renderer)]
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4198                     # this artist
#    4199                     continue
# -> 4200             bbox = a.get_tightbbox(renderer)
#    4201             if (bbox is not None
#    4202                     and 0 < bbox.width < np.inf
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\artist.py in get_tightbbox(self, renderer)
#     276             The enclosing bounding box (in figure pixel coordinates).
#     277         """
# --> 278         bbox = self.get_window_extent(renderer)
#     279         if self.get_clip_on():
#     280             clip_box = self.get_clip_box()
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\spines.py in get_window_extent(self, renderer)
#     208             bboxes.append(bb0)
#     209
# --> 210         return mtransforms.Bbox.union(bboxes)
#     211
#     212     def get_path(self):
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\transforms.py in union(bboxes)
#     664         # can remove once we are at numpy >= 1.16
#     665         with np.errstate(invalid='ignore'):
# --> 666             x0 = np.min([bbox.xmin for bbox in bboxes])
#     667             x1 = np.max([bbox.xmax for bbox in bboxes])
#     668             y0 = np.min([bbox.ymin for bbox in bboxes])
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\transforms.py in <listcomp>(.0)
#     664         # can remove once we are at numpy >= 1.16
#     665         with np.errstate(invalid='ignore'):
# --> 666             x0 = np.min([bbox.xmin for bbox in bboxes])
#     667             x1 = np.max([bbox.xmax for bbox in bboxes])
#     668             y0 = np.min([bbox.ymin for bbox in bboxes])
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\matplotlib\transforms.py in xmin(self)
#     310     def xmin(self):
#     311         """The left edge of the bounding box."""
# --> 312         return np.min(self.get_points()[:, 0])
#     313
#     314     @property
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# ~\Anaconda3\envs\AI_lecture\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:

# %% [markdown]
# ### [TIP1] sns.box을 이용하여 설명변수의 특성을 파악

# %%
fig, ax = plt.subplots(figsize=(35, 10))
boxplot = sns.boxplot(data=data,ax=ax, width=0.5)
boxplot.tick_params(labelsize=10)
plt.savefig('boxplot.png')

# %% [markdown]
# ### [TIP2] 분석에 앞서 Class distribution 확인
# ### Class 불균형 발생시, 일반적인 모델링으로는 우수한 성능을 내기 어려움

# %%
# Check class label distribution
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7, 7))
sns.countplot(data['diagnosis'], palette='Set1', ax=ax)
ax.set_title("B : M = {} : {}".format(*data['diagnosis'].value_counts()))
plt.show()

# %% [markdown]
# ### [TIP3] 변수간 Correlation 확인

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))
ax = sns.heatmap(data.drop(['diagnosis'], axis=1).corr(), annot=True, fmt='.1f')
ax.set_title("Correlation Heatmap of X variables")
plt.tight_layout()
plt.show(fig)

# %% [markdown]
# ## 4. 데이터 전처리
#
# $\mathbf{X}$: 설명변수/입력변수 <br>
# $\mathbf{y}$: 반응변수/출력변수

# %%
X = data.drop(['diagnosis'], axis=1)
#X = X.iloc[:, :10]
y = data['diagnosis']

# %% [markdown]
# ### 학습을 위해 Train / Test 데이터 분리

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=1/10,
                                                    stratify=y,
                                                    random_state=2015010720)

# %% [markdown]
# ### Train 데이터에 대해
# ### 1. scaling을 통한 변수 범위 일치
# ### 2. validation set 분리 - parameter 튜닝 목적

# %%
#scaler = StandardScaler()
#scaler = MinMaxScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)


X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size=1/9,
                                                      stratify=y_train,
                                                      random_state=2015010720)

# %% [markdown]
# ## 5. 모델 구축 (Decision tree)
# ### 풀고자 하는 문제의 종류에 따라 다른 criterion 사용이 필요함
# #### 분류문제 : gini index 사용
# #### 회귀문제 : mse

# %%
clf_dt = DecisionTreeClassifier(criterion='gini', max_depth=None)
clf_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### 6.평가 및 예측 수행(train / valid)

# %%
y_train_pred = clf_dt.predict(X_train)
y_valid_pred = clf_dt.predict(X_valid)

# Show train & validation accuracies
print('- Accuracy (Train)      : {:.4}'.format(accuracy_score(y_train, y_train_pred)))
print('- Accuracy (Validation) : {:.4}'.format(accuracy_score(y_valid, y_valid_pred)))
# Show train & validation f1 scores
print('- F1 score (Train)      : {:.4}'.format(f1_score(y_train, y_train_pred, pos_label='M')))
print('- F1 score (Validation) : {:.4}'.format(f1_score(y_valid, y_valid_pred, pos_label='M')))

# Show train & validation Precision scores
print('- precision score (Train)      : {:.4}'.format(precision_score(y_train, y_train_pred, pos_label='M')))
print('- precision score (Validation) : {:.4}'.format(precision_score(y_valid, y_valid_pred, pos_label='M')))

# Show train & validation recall scores
print('- recall score (Train)      : {:.4}'.format(recall_score(y_train, y_train_pred, pos_label='M')))
print('- recall score (Validation) : {:.4}'.format(recall_score(y_valid, y_valid_pred, pos_label='M')))

# %%
y_score_train =clf_dt.predict_proba(X_train)
y_score_valid =clf_dt.predict_proba(X_valid)

# %%
# Show ROC AUC
fpr, tpr, thresholds =  roc_curve(y_valid, y_score_valid[:,1], pos_label='M')
print(auc(fpr, tpr))
# Out:
# 0.9146825396825397

# %% [markdown]
# ## Decision Tree의 장점은 데이터 분할 기준에 따른 규칙 생성이 가능
# ### 규칙의 시각화

# %%
graph = Source(export_graphviz(clf_dt,
                               out_file=None,
                               feature_names=X.columns,
                               filled=True,
                               leaves_parallel=False))
Image(graph.pipe(format='png'))

# %% [markdown]
# ### 데이터에 적합한 모델을 구축하기 위해 parameter 튜닝이 필요함
# #### DT에는 모델의 depth를 적정하게 설정하는 것이 중요함 (overfitting 가능성 최소화)

# %%
max_depths = list(range(1, 9, 1))
validation_accs = []
validation_f1 = []
dt_models = []
for max_depth in max_depths:
    clf_dt = DecisionTreeClassifier(criterion='gini', max_depth=max_depth)
    clf_dt.fit(X_train, y_train)
    dt_models.append(clf_dt)
    y_valid_pred = clf_dt.predict(X_valid)
    validation_accs.append(accuracy_score(y_valid, y_valid_pred))
    validation_f1.append(f1_score(y_valid, y_valid_pred, pos_label='M'))

# %%
fig, ax = plt.subplots(figsize=(7, 7))
ax.plot(max_depths, validation_accs, color='red', marker='o', label='validation acc')
ax.plot(max_depths, validation_f1, color='blue', marker='s', label='validation f1')
ax.legend(loc='best')
plt.show(fig)

# %% [markdown]
# ### Validation set에 대해 우수한 성능을 보였던 depth는 3 또는 4
# #### 우리는 depth를 3,4로 설정할때 test set에 대해서도 상대적으로 우수한 성능을 보일것이라 기대할 수 있음

# %%
best_model_idx, best_model_f1 = max(enumerate(validation_f1), key=lambda p: p[1])
y_test_pred = dt_models[best_model_idx].predict(X_test)
print('- Accuracy (Test) : {:.4}'.format(accuracy_score(y_test, y_test_pred)))
print('- F1 score (Test) : {:.4}'.format(f1_score(y_test, y_test_pred, pos_label='M')))
# Out:
# - Accuracy (Test) : 0.9649
# - F1 score (Test) : 0.95

# %%
cm_test = confusion_matrix(y_test, y_test_pred)
cm_test = pd.DataFrame(cm_test, columns=['B', 'M'])
sns.heatmap(data=cm_test, annot=True, annot_kws={'size': 18})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Best Model에 대한 규칙 (시각화)

# %%
graph = Source(export_graphviz(dt_models[best_model_idx],
                               out_file=None,
                               feature_names=X.columns,
                               filled=True,
                               leaves_parallel=True))
png_bytes = graph.pipe(format='png')
Image(png_bytes)

# %%
with open('dt_best.png', 'wb') as f:
    f.write(png_bytes)

# %% [markdown]
# ### DT는 규칙을 시각적으로 제공이 가능할 뿐만 아니라
# ### 각 변수의 중요도를 제공 (Linear regression의 coefficient와 유사한 개념)

# %%
imp = dt_models[best_model_idx].feature_importances_
imp = pd.DataFrame([X.columns, imp]).T
imp.columns = ['variables', 'importance']
print(imp[imp['importance'] != 0])
# Out:
#                variables importance
# 6         concavity_mean   0.006958
# 7    concave points_mean   0.023262
# 16          concavity_se   0.022079
# 20          radius_worst   0.110741
# 21         texture_worst   0.044404
# 27  concave points_worst   0.792556

# %%
fig, ax = plt.subplots(figsize=(7, 7))
sns.barplot(x='variables', y='importance', data=imp, ax=ax)
plt.setp(ax.get_xticklabels(), rotation=90)
plt.show(fig)

# %% [markdown]
# ### 변수의 중요가 높다 = 분류(또는 회귀)를 수행하는데 critical한 역활을 한다
# ### 중요도 순위가 높은 2개의 변수를 사용하여 2차원 시각화를 수행

# %%
sns.lmplot(x='concave points_worst', y='texture_worst',
           hue='diagnosis', data=data, fit_reg=False)
